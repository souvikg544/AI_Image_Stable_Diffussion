# %% [markdown]
# <a href="https://colab.research.google.com/github/souvikg544/AI_Image_Stable_Diffussion/blob/main/stable_diffusion_videos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Stable Diffusion Videos
#
# This notebook allows you to generate videos by interpolating the latent space of [Stable Diffusion](https://github.com/CompVis/stable-diffusion).
#
# You can either dream up different versions of the same prompt, or morph between different text prompts (with seeds set for each for reproducibility).
#
# If you like this notebook:
# - consider giving the [repo a star](https://github.com/nateraw/stable-diffusion-videos) ⭐️
# - consider following me on Github [@nateraw](https://github.com/nateraw)
#
# You can file any issues/feature requests [here](https://github.com/nateraw/stable-diffusion-videos/issues)
#
# Enjoy 🤗

# %% [markdown]
# ## Setup

# %%
! pip install stable_diffusion_videos
! git config --global credential.helper store
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting stable_diffusion_videos
#   Downloading stable_diffusion_videos-0.1.2-py3-none-any.whl (13 kB)
# Collecting diffusers==0.3.0
#   Downloading diffusers-0.3.0-py3-none-any.whl (153 kB)
#      |████████████████████████████████| 153 kB 33.8 MB/s
# Collecting fire
#   Downloading fire-0.4.0.tar.gz (87 kB)
#      |████████████████████████████████| 87 kB 6.6 MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from stable_diffusion_videos) (1.7.3)
# Collecting transformers
#   Downloading transformers-4.21.3-py3-none-any.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 56.5 MB/s
# Collecting gradio
#   Downloading gradio-3.3-py3-none-any.whl (6.1 MB)
#      |████████████████████████████████| 6.1 MB 44.5 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from diffusers==0.3.0->stable_diffusion_videos) (2022.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from diffusers==0.3.0->stable_diffusion_videos) (3.8.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from diffusers==0.3.0->stable_diffusion_videos) (7.1.2)
# Collecting huggingface-hub>=0.8.1
#   Downloading huggingface_hub-0.9.1-py3-none-any.whl (120 kB)
#      |████████████████████████████████| 120 kB 63.8 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from diffusers==0.3.0->stable_diffusion_videos) (2.23.0)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.7/dist-packages (from diffusers==0.3.0->stable_diffusion_videos) (1.12.1+cu113)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from diffusers==0.3.0->stable_diffusion_videos) (1.21.6)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from diffusers==0.3.0->stable_diffusion_videos) (4.12.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.8.1->diffusers==0.3.0->stable_diffusion_videos) (6.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.8.1->diffusers==0.3.0->stable_diffusion_videos) (4.64.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.8.1->diffusers==0.3.0->stable_diffusion_videos) (21.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.8.1->diffusers==0.3.0->stable_diffusion_videos) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.9->huggingface-hub>=0.8.1->diffusers==0.3.0->stable_diffusion_videos) (3.0.9)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from fire->stable_diffusion_videos) (1.15.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.7/dist-packages (from fire->stable_diffusion_videos) (1.1.0)
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting uvicorn
#   Downloading uvicorn-0.18.3-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 4.6 MB/s
# Collecting markdown-it-py[linkify,plugins]
#   Downloading markdown_it_py-2.1.0-py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 3.2 MB/s
# Collecting ffmpy
#   Downloading ffmpy-0.3.0.tar.gz (4.8 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from gradio->stable_diffusion_videos) (1.3.5)
# Collecting paramiko
#   Downloading paramiko-2.11.0-py2.py3-none-any.whl (212 kB)
#      |████████████████████████████████| 212 kB 51.1 MB/s
# Requirement already satisfied: pydantic in /usr/local/lib/python3.7/dist-packages (from gradio->stable_diffusion_videos) (1.9.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from gradio->stable_diffusion_videos) (3.2.2)
# Collecting fastapi
#   Downloading fastapi-0.82.0-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 3.1 MB/s
# Collecting orjson
#   Downloading orjson-3.8.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (270 kB)
#      |████████████████████████████████| 270 kB 68.6 MB/s
# Collecting python-multipart
#   Downloading python-multipart-0.0.5.tar.gz (32 kB)
# Collecting pycryptodome
#   Downloading pycryptodome-3.15.0-cp35-abi3-manylinux2010_x86_64.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 41.2 MB/s
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from gradio->stable_diffusion_videos) (3.8.1)
# Collecting analytics-python
#   Downloading analytics_python-1.4.0-py2.py3-none-any.whl (15 kB)
# Collecting h11<0.13,>=0.11
#   Downloading h11-0.12.0-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 3.6 MB/s
# Collecting httpx
#   Downloading httpx-0.23.0-py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 3.5 MB/s
# Requirement already satisfied: Jinja2 in /usr/local/lib/python3.7/dist-packages (from gradio->stable_diffusion_videos) (2.11.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.7/dist-packages (from gradio->stable_diffusion_videos) (2022.8.1)
# Collecting websockets
#   Downloading websockets-10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (112 kB)
#      |████████████████████████████████| 112 kB 75.8 MB/s
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->gradio->stable_diffusion_videos) (2.1.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->gradio->stable_diffusion_videos) (22.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->gradio->stable_diffusion_videos) (1.8.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->gradio->stable_diffusion_videos) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->gradio->stable_diffusion_videos) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->gradio->stable_diffusion_videos) (6.0.2)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->gradio->stable_diffusion_videos) (0.13.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->gradio->stable_diffusion_videos) (1.2.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.7/dist-packages (from yarl<2.0,>=1.0->aiohttp->gradio->stable_diffusion_videos) (2.10)
# Collecting monotonic>=1.5
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Requirement already satisfied: python-dateutil>2.1 in /usr/local/lib/python3.7/dist-packages (from analytics-python->gradio->stable_diffusion_videos) (2.8.2)
# Collecting backoff==1.10.0
#   Downloading backoff-1.10.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->diffusers==0.3.0->stable_diffusion_videos) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->diffusers==0.3.0->stable_diffusion_videos) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->diffusers==0.3.0->stable_diffusion_videos) (1.24.3)
# Collecting starlette==0.19.1
#   Downloading starlette-0.19.1-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 957 kB/s
# Collecting anyio<5,>=3.4.0
#   Downloading anyio-3.6.1-py3-none-any.whl (80 kB)
#      |████████████████████████████████| 80 kB 10.1 MB/s
# Collecting sniffio>=1.1
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting rfc3986[idna2008]<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting httpcore<0.16.0,>=0.15.0
#   Downloading httpcore-0.15.0-py3-none-any.whl (68 kB)
#      |████████████████████████████████| 68 kB 6.6 MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->diffusers==0.3.0->stable_diffusion_videos) (3.8.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2->gradio->stable_diffusion_videos) (2.0.1)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting mdit-py-plugins
#   Downloading mdit_py_plugins-0.3.0-py3-none-any.whl (43 kB)
#      |████████████████████████████████| 43 kB 2.2 MB/s
# Collecting linkify-it-py~=1.0
#   Downloading linkify_it_py-1.0.3-py3-none-any.whl (19 kB)
# Collecting uc-micro-py
#   Downloading uc_micro_py-1.0.1-py3-none-any.whl (6.2 kB)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->gradio->stable_diffusion_videos) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->gradio->stable_diffusion_videos) (1.4.4)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->gradio->stable_diffusion_videos) (2022.2.1)
# Collecting cryptography>=2.5
#   Downloading cryptography-38.0.1-cp36-abi3-manylinux_2_24_x86_64.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 27.6 MB/s
# Collecting pynacl>=1.0.1
#   Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (856 kB)
#      |████████████████████████████████| 856 kB 71.7 MB/s
# Collecting bcrypt>=3.1.3
#   Downloading bcrypt-4.0.0-cp36-abi3-manylinux_2_24_x86_64.whl (594 kB)
#      |████████████████████████████████| 594 kB 63.9 MB/s
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=2.5->paramiko->gradio->stable_diffusion_videos) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=2.5->paramiko->gradio->stable_diffusion_videos) (2.21)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 62.8 MB/s
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.7/dist-packages (from uvicorn->gradio->stable_diffusion_videos) (7.1.2)
# Building wheels for collected packages: fire, ffmpy, python-multipart
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115942 sha256=e105f04802ff9c8ab9769a6c3dc4e126e3b169f5e2067e452fd6ccc30af1999d
#   Stored in directory: /root/.cache/pip/wheels/8a/67/fb/2e8a12fa16661b9d5af1f654bd199366799740a85c64981226
#   Building wheel for ffmpy (setup.py) ... done
#   Created wheel for ffmpy: filename=ffmpy-0.3.0-py3-none-any.whl size=4712 sha256=c1a75c652e7fbac937c7482d87e6e8297fdedac5b7ebb5905e6b929660cbe0a5
#   Stored in directory: /root/.cache/pip/wheels/13/e4/6c/e8059816e86796a597c6e6b0d4c880630f51a1fcfa0befd5e6
#   Building wheel for python-multipart (setup.py) ... done
#   Created wheel for python-multipart: filename=python_multipart-0.0.5-py3-none-any.whl size=31678 sha256=b73cad95dee878f214fa4d3c75a0cb9d5cbfffc9450e3b22b7b8699bc6bb89c7
#   Stored in directory: /root/.cache/pip/wheels/2c/41/7c/bfd1c180534ffdcc0972f78c5758f89881602175d48a8bcd2c
# Successfully built fire ffmpy python-multipart
# Installing collected packages: sniffio, mdurl, uc-micro-py, rfc3986, markdown-it-py, h11, anyio, starlette, pynacl, monotonic, mdit-py-plugins, linkify-it-py, httpcore, cryptography, bcrypt, backoff, websockets, uvicorn, tokenizers, python-multipart, pydub, pycryptodome, paramiko, orjson, huggingface-hub, httpx, ffmpy, fastapi, analytics-python, transformers, gradio, fire, diffusers, stable-diffusion-videos
# Successfully installed analytics-python-1.4.0 anyio-3.6.1 backoff-1.10.0 bcrypt-4.0.0 cryptography-38.0.1 diffusers-0.3.0 fastapi-0.82.0 ffmpy-0.3.0 fire-0.4.0 gradio-3.3 h11-0.12.0 httpcore-0.15.0 httpx-0.23.0 huggingface-hub-0.9.1 linkify-it-py-1.0.3 markdown-it-py-2.1.0 mdit-py-plugins-0.3.0 mdurl-0.1.2 monotonic-1.6 orjson-3.8.0 paramiko-2.11.0 pycryptodome-3.15.0 pydub-0.25.1 pynacl-1.5.0 python-multipart-0.0.5 rfc3986-1.5.0 sniffio-1.3.0 stable-diffusion-videos-0.1.2 starlette-0.19.1 tokenizers-0.12.1 transformers-4.21.3 uc-micro-py-1.0.1 uvicorn-0.18.3 websockets-10.3

# %% [markdown]
# ## Authenticate with Hugging Face Hub
#
# You have to be a registered user in 🤗 Hugging Face Hub, and you'll also need to use an access token for the code to work. For more information on access tokens, please refer to [this section of the documentation](https://huggingface.co/docs/hub/security-tokens).

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# Login successful
# Your token has been saved to /root/.huggingface/token

# %% [markdown]
# ## Run the App 🚀

# %% [markdown]
# ### Load the Interface
#
# This step will take a couple minutes the first time you run it.

# %%
from stable_diffusion_videos import interface
# Out:
# Downloading:   0%|          | 0.00/1.34k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/12.5k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/342 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/543 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.63k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/608M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/209 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/209 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/572 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/246M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/525k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/472 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/788 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/772 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.72G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/71.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/550 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/167M [00:00<?, ?B/s]
# {'trained_betas'} was not found in config. Values will be initialized to default values.
# ftfy or spacy is not installed using BERT BasicTokenizer instead of ftfy.
# /usr/local/lib/python3.7/dist-packages/gradio/blocks.py:592: UserWarning: api_name predict already exists, using predict_1
#   api_name, api_name_

# %%
#@title Connect to Google Drive to Save Outputs

#@markdown If you want to connect Google Drive, click the checkbox below and run this cell. You'll be prompted to authenticate.

#@markdown If you just want to save your outputs in this Colab session, don't worry about this cell

connect_google_drive = True #@param {type:"boolean"}

#@markdown Then, in the interface, use this path as the `output` in the Video tab to save your videos to Google Drive:

#@markdown > /content/gdrive/MyDrive/stable_diffusion_videos


if connect_google_drive:
    from google.colab import drive

    drive.mount('/content/gdrive')

# %% [markdown]
# ### Launch
#
# This cell launches a Gradio Interface. Here's how I suggest you use it:
#
# 1. Use the "Images" tab to generate images you like.
#     - Find two images you want to morph between
#     - These images should use the same settings (guidance scale, height, width)
#     - Keep track of the seeds/settings you used so you can reproduce them
#
# 2. Generate videos using the "Videos" tab
#     - Using the images you found from the step above, provide the prompts/seeds you recorded
#     - Set the `num_walk_steps` - for testing you can use a small number like 3 or 5, but to get great results you'll want to use something larger (60-200 steps).
#
# 💡 **Pro tip** - Click the link that looks like `https://<id-number>.gradio.app` below , and you'll be able to view it in full screen.

# %%
interface.launch()
# Out:
# Colab notebook detected. To show errors in colab notebook, set `debug=True` in `launch()`
# Running on public URL: https://26614.gradio.app
#
# This share link expires in 72 hours. For free permanent hosting, check out Spaces: https://huggingface.co/spaces
# <div><iframe src="https://26614.gradio.app" width="900" height="500" allow="autoplay; camera; microphone;" frameborder="0" allowfullscreen></iframe></div>
# (<gradio.routes.App at 0x7f30c555ced0>,
#  'http://127.0.0.1:7860/',
#  'https://26614.gradio.app')

# %% [markdown]
# ---

# %% [markdown]
# ## Use `walk` programatically
#
# The other option is to not use the interface, and instead use `walk` programatically. Here's how you would do that...

# %% [markdown]
# First we define a helper fn for visualizing videos in colab

# %%
from IPython.display import HTML
from base64 import b64encode

def visualize_video_colab(video_path):
    mp4 = open(video_path,'rb').read()
    data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
    return HTML("""
    <video width=400 controls>
        <source src="%s" type="video/mp4">
    </video>
    """ % data_url)

# %% [markdown]
# Walk! 🚶‍♀️

# %%
from stable_diffusion_videos import walk

video_path = walk(['a cat', 'a dog'], [42, 1337], num_steps=3, make_video=True)
visualize_video_colab(video_path)
# Out:
# COUNT: 1/3
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#     <video width=400 controls>
#         <source src="data:video/mp4;base64,..." type="video/mp4">
#     </video>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/dreams/20220909-113127/20220909-113127.mp4 /content/drive/MyDrive/whilter_videos
